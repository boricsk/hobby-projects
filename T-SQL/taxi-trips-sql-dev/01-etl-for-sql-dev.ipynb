# %%
import pandas as pd
import requests
import os
from dateutil.relativedelta import relativedelta
from datetime import datetime as dt
import json

pd.set_option('display.max_columns',30)

# %%
start_date = (dt.now() - relativedelta(months=2)).strftime("%Y-%m-%d")
url_new = f"https://data.cityofchicago.org/resource/ajtu-isnz.json?$where=trip_start_timestamp >= '{start_date}T00:00:00' AND trip_start_timestamp <= '{start_date}T23:59:59'&$limit=213000000"
response_taxi = requests.get(url_new)
taxi_data = response_taxi.json()

# %%
taxi_trips = pd.DataFrame(taxi_data)

# %%
taxi_trips.drop(['pickup_census_tract', 'dropoff_census_tract'], axis=1, inplace=True)
taxi_trips.drop(['pickup_centroid_location', 'dropoff_centroid_location'], axis=1, inplace=True)
taxi_trips.dropna(inplace=True)

# %%
taxi_trips.head(5)
# Out:
#                                     trip_id  \
# 0  05328f177362e305a9497e46bc83a8ae385d3207
# 2  f5aa252af916db7fac11f31df95deff6a1e03148
# 3  f0a54d00b2015a21c7df0566c6b254627b671706
# 4  efb3465a26456584a5230f7f96578f67eff04c3d
# 5  ec3db0cc2b24e9056cafbd7032d901fb55c1d805
#
#                                              taxi_id     trip_start_timestamp  \
# 0  c7a8a53874bbcdb11e70a488485e8bdd0bb8cc0de8f5d9...  2024-04-09T23:45:00.000
# 2  342474dd3a24c9d5b7dbc2514032a01ecb396624638be5...  2024-04-09T23:45:00.000
# 3  c3f8e0b6712bf3ea80e75ddde065b0ed42aa530e8c40cb...  2024-04-09T23:45:00.000
# 4  57c40509cae37a0e5e536a657cdb7f8c6824314bc466a7...  2024-04-09T23:45:00.000
# 5  3577d72a8bf30406c1346a5e178b7f3a0ce8e1f966f59a...  2024-04-09T23:45:00.000
#
#         trip_end_timestamp trip_seconds trip_miles pickup_community_area  \
# 0  2024-04-10T00:00:00.000         1059      12.87                    39
# 2  2024-04-10T00:15:00.000         1560       15.6                    56
# 3  2024-04-10T00:00:00.000         1615      13.12                    76
# 4  2024-04-10T00:15:00.000         1800          0                    51
# 5  2024-04-10T00:00:00.000          703       2.59                    24
#
#   dropoff_community_area   fare  tips tolls extras trip_total payment_type  \
# 0                     56  32.75     0     0      0      32.75       Prcard
# 2                      8   39.5     0     0      5       44.5  Credit Card
# 3                     22  34.75  5.89     0      4      45.14       Mobile
# 4                     38  23.75     0     0      0      23.75      Unknown
# 5                     23      9  2.23     0      0      11.23       Mobile
#
#                         company pickup_centroid_latitude  \
# 0                     Flash Cab             41.808916283
# 2     Taxi Affiliation Services              41.79259236
# 3                  City Service             41.980264315
# 4     Taxi Affiliation Services             41.690633347
# 5  Tac - Yellow Cab Association             41.901206994
#
#   pickup_centroid_longitude dropoff_centroid_latitude  \
# 0             -87.596183344               41.79259236
# 2             -87.769615453              41.899602111
# 3             -87.913624596               41.92276062
# 4             -87.570058269              41.812948939
# 5             -87.676355989              41.900069603
#
#   dropoff_centroid_longitude
# 0              -87.769615453
# 2              -87.633308037
# 3              -87.699155343
# 4              -87.617859676
# 5              -87.720918238

# %%
taxi_trips.to_csv(f'taxi_trips {start_date}.csv', index=False, sep = ';', encoding = 'utf-16')
